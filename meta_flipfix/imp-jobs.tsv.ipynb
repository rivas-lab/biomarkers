# %%
require(tidyverse)
require(data.table)
# Out:
# Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.2
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   1.0.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Loading required package: data.table
#
# Attaching package: ‘data.table’
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
# The following object is masked from ‘package:purrr’:
#
#     transpose

# %%
gwas <- fread('gwas_imp_WB.lst', head=F)
colnames(gwas) <- c('phe', 'gwas')

# %%
meta <- fread('imp-jobs.lst', head=F)
colnames(meta) <- c('meta')

# %%
master <- meta %>% 
mutate(phe = str_replace_all(meta, '^/oak/stanford/groups/mrivas/projects/biomarkers/meta/plink_imputed/filtered/GLOBAL_|.sumstats.tsv.gz$', '')) %>%
inner_join(gwas) %>%
select(phe, meta, gwas)
# Out:
# Joining, by = "phe"

# %%
master %>% fwrite('imp-jobs.tsv', sep='\t')

# %%
master %>% dim()
# Out:
# [1] 40  3
