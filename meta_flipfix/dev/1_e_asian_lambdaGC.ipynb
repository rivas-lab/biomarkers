# %%
suppressWarnings(suppressPackageStartupMessages({
    library(tidyverse)
    library(data.table)
}))

# %%
'@@@@@@/ukbb24983/array-combined/ldsc/h2.e_asian.tsv' %>% fread() %>%
rename('GBE_ID'='#p') -> h2_df

# %%
'../../common/biomarker.phenotype.info.tsv' %>% fread() -> phe_info_df

# %%
phe_info_df %>%
select(name, Abbreviation, `GBE ID`) %>%
left_join(
    h2_df, by=c('GBE ID' = 'GBE_ID')
)
# Out:
#    name                       Abbreviation GBE ID      h2_obs  h2_obs_se
# 1  Alanine aminotransferase   ALT          INI10030620      NA     NA
# 2  Albumin                    ALB          INI10030600      NA     NA
# 3  Alkaline phosphatase       ALP          INI10030610      NA     NA
# 4  Apolipoprotein A           APOA         INI10030630  0.6673 0.4821
# 5  Apolipoprotein B           APOB         INI20030640  1.3632 0.4525
# 6  Aspartate aminotransferase AST          INI10030650      NA     NA
# 7  AST to ALT ratio           AST2ALT      INI30030650 -0.3038 0.3418
# 8  C-reactive protein         CRP          INI10030710      NA     NA
# 9  Calcium                    CA           INI10030680      NA     NA
# 10 Cholesterol                CHOL         INI20030690  0.4958 0.4361
# 11 Creatinine                 CRE          INI10030700      NA     NA
# 12 Creatinine in urine        UCR          INI10030510      NA     NA
# ...

# %%
phe_info_df %>%
select(name, Abbreviation, `GBE ID`) %>%
inner_join(
    h2_df, by=c('GBE ID' = 'GBE_ID')
)
# Out:
#    name                Abbreviation GBE ID      h2_obs  h2_obs_se lambda_GC
# 1  Apolipoprotein A    APOA         INI10030630  0.6673 0.4821    1.0075
# 2  Apolipoprotein B    APOB         INI20030640  1.3632 0.4525    1.0285
# 3  AST to ALT ratio    AST2ALT      INI30030650 -0.3038 0.3418    0.9898
# 4  Cholesterol         CHOL         INI20030690  0.4958 0.4361    1.0225
# 5  eGFR                EGFR         INI30030700 -0.3811 0.3845    0.9868
# 6  Glucose             GLU          INI10030740 -0.0948 0.6094    1.0135
# 7  HbA1c               HBA1C        INI10030750  0.6374 0.4271    0.9839
# 8  HDL cholesterol     HDL          INI10030760 -0.1847 0.4206    1.0165
# 9  IGF-1               IGF1         INI10030770  1.2311 0.4396    1.0016
# 10 LDL cholesterol     LDLD         INI20030780  0.3001 0.4065    1.0315
# 11 Lipoprotein A       LPA          INI10030790 -0.1174 0.3950    1.0165
# 12 Non-albumin protein NAP          INI30030860 -0.0847 0.4849    1.0046
# ...
