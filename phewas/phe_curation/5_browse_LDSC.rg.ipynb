# %%
suppressWarnings(suppressPackageStartupMessages({
    library(tidyverse)
    library(data.table)
    library(corrplot)
}))

# %%
in_f <- 'ldscrg.tsv'
phenos_f <- '../phenotypes.txt'
plot_png_f <- "rg.png"

# %%
phenos_f %>% fread() -> phenos

in_f %>% fread() %>% 
mutate(
    p1 = str_replace_all(basename(p1), '^ukb24983_v2_hg19.|.array-combined.sumstats.gz$', ''),
    p2 = str_replace_all(basename(p2), '^ukb24983_v2_hg19.|.array-combined.sumstats.gz$', '')
) %>%
filter(!str_detect(p1, '^RH')) %>% 
filter(!str_detect(p2, '^RH')) %>%
mutate(rgg = if_else(abs(rg) > 1, sign(rg), rg)) -> df

# %%
df %>%
dim()
# Out:
# [1] 28561    13

# %%
df %>%
filter(is.na(rgg)) %>%
select(p1, p2) %>%
gather(col, val) %>%
count(val) %>%
arrange(-n) %>%
filter(n > 10)
# Out:
#   val   n
# 1 HC107 338
# 2 HC209 336
# 3 HC74  336
# 4 HC405 314

# %%
df %>%
filter(p1 == 'HC107') %>%
head()
# Out:
#   p1    p2         rg se z  p  h2_obs h2_obs_se h2_int h2_int_se gcov_int
# 1 HC107 BIN20406   NA NA NA NA 0.4265 0.0863    0.9787 0.0057    0.0032
# 2 HC107 BIN21068   NA NA NA NA 0.0829 0.0409    0.9639 0.0182    0.0093
# 3 HC107 BIN1020483 NA NA NA NA 0.0061 0.0016    0.9972 0.0060    0.0204
# 4 HC107 FH1262     NA NA NA NA 0.0056 0.0018    0.9898 0.0058    0.0024
# 5 HC107 HC0        NA NA NA NA 0.0067 0.0017    0.9817 0.0059    0.0173
# 6 HC107 HC1        NA NA NA NA 0.0018 0.0015    0.9986 0.0060    0.0087
#   gcov_int_se rgg
# 1 0.0039      NA
# 2 0.0043      NA
# 3 0.0048      NA
# 4 0.0038      NA
# 5 0.0044      NA
# 6 0.0042      NA

# %%
png(file = "rg.png", width=2400,height=2400, units="px", family = "Helvetica")
corrplot(
    df %>%
    replace_na(list(rgg=0)) %>%
    dcast(p1 ~ p2, value.var = "rgg", fill=0) %>%
    column_to_rownames('p1') %>%
    as.matrix(),
    order='hclust',
    addrect = 100
)
dev.off()
# Out:
# png
#   2

# %%
28561 / 2
# Out:
# [1] 14280.5

# %%
0.05 /15000
# Out:
# [1] 3.333333e-06

# %%
df %>%
filter(p1 < p2) %>%
arrange(p) %>%
filter(p < 5e-6) %>%
rename('GBE_ID_1'='p1', 'GBE_ID_2'='p2') %>%
left_join(phenos, by=c('GBE_ID_1'='GBE_ID')) %>%
rename('name_1'='Name', 'n_1'='Cases') %>%
left_join(phenos, by=c('GBE_ID_2'='GBE_ID')) %>%
rename('name_2'='Name', 'n_2'='Cases') %>%
select(GBE_ID_1, name_1, GBE_ID_2, name_2, p, rg, se, z, n_1, n_2)
# Out:
#     GBE_ID_1       name_1
# 1   HC188          Cholelithiasis/gall stones
# 2   cancer1001     Lung cancer
# 3   cancer1003     Skin cancer
# 4   BIN_FC1006152  DVT diagnosed by doctor
# 5   cancer1020     Large bowel cancer/colorectal cancer
# 6   HC201          Ulcerative colitis
# 7   HC308          Hypertrophic cardiomyopathy (HCM / HOCM)
# 8   HC132          Angina
# 9   HC132          Angina
# 10  HC215          Hypertension
# 11  BIN_FC5006152  Hayfever rhinitis or eczema diagnosed by doctor
# 12  HC125          Anaemia
# 13  HC215          Hypertension
# 14  cancer1047     Lymphoma
# 15  HC132          Angina
# 16  cancer1038     Male genital tract cancer
# 17  HC164          Gastro-oesophageal reflux (GORD) / gastric reflux
# 18  HC106          Emphysema/chronic bronchitis
# 19  cancer1020     Large bowel cancer/colorectal cancer
# 20  HC322          Crohns disease
# 21  HC221          Diabetes
# 22  BIN_FC1006148  Eye problems/disorders Diabetic eye disease
# 23  HC219          Hypothyroidism/myxoedema
# 24  BIN_FC6006149  Dentures
# 25  HC38           Psoriasis
# 26  cancer1035     Bladder cancer
# 27  HC362          Respiratory infection
# 28  HC221          Diabetes
# 29  BIN_FC10002834 Bilateral oophorectomy (both ovaries removed)
# 30  HC215          Hypertension
# ⋮   ⋮              ⋮
# 153 HC133          Anal fissure
# 154 BIN_FC6006149  Dentures
# 155 HC219          Hypothyroidism/myxoedema
# 156 BIN_FC10002834 Bilateral oophorectomy (both ovaries removed)
# 157 BIN_FC10003591 Ever had hysterectomy (womb removed)
# 158 BIN_FC10003591 Ever had hysterectomy (womb removed)
# 159 BIN_FC3002247  Hearing difficulty and Deafness
# 160 BIN_FC1006148  Eye problems/disorders Diabetic eye disease
# 161 HC326          Heart attack/myocardial infarction
# 162 HC185          Cellulitis
# 163 HC442          Chronic obstructive airways disease/COPD
# 164 HC221          Diabetes
# 165 HC188          Cholelithiasis/gall stones
# 166 HC164          Gastro-oesophageal reflux (GORD) / gastric reflux
# 167 BIN_FC6006149  Dentures
# 168 HC385          Peripheral vascular disease
# 169 HC219          Hypothyroidism/myxoedema
# 170 HC136          Connective tissue disorder
# 171 HC215          Hypertension
# 172 HC25           Cataract
# 173 cancer1003     Skin cancer
# 174 HC188          Cholelithiasis/gall stones
# 175 HC219          Hypothyroidism/myxoedema
# 176 HC364          Sleep apnoea
# 177 HC295          Carpal tunnel syndrome
# 178 HC185          Cellulitis
# 179 HC299          Heart failure/pulmonary odema
# 180 HC164          Gastro-oesophageal reflux (GORD) / gastric reflux
# 181 HC106          Emphysema/chronic bronchitis
# 182 BIN21068       Diagnosed with Coeliac disease or gluten sensitivity
#     GBE_ID_2       name_2                                   p           rg
# 1   HC225          Cholecystitis                             0.0000e+00 0.9994
# 2   cancer1084     Respiratory/intrathoracic cancer          0.0000e+00 0.9492
# 3   cancer1060     Non-melanoma skin cancer                  0.0000e+00 0.9913
# 4   BIN_FC11006152 Blood clot or DVT diagnosed by doctor     0.0000e+00 0.9784
# 5   cancer1022     Colon cancer/sigmoid cancer              2.3998e-297 1.0092
# 6   HC95           Inflammatory bowel disease               8.4017e-237 0.9348
# 7   HC414          Cardiomyopathy                           2.3183e-157 0.9122
# 8   HC326          Heart attack/myocardial infarction       9.4273e-105 0.8774
# 9   HC215          Hypertension                              2.0677e-70 0.5618
# 10  HC221          Diabetes                                  1.3011e-62 0.4679
# 11  HC382          Asthma                                    3.4420e-58 0.6776
# 12  HC179          Iron deficiency anaemia                   3.6628e-45 0.9768
# 13  HC326          Heart attack/myocardial infarction        1.2643e-41 0.5437
# 14  cancer1053     Non-Hodgkins lymphoma                     1.3191e-37 0.8921
# 15  HC221          Diabetes                                  5.5316e-36 0.5008
# 16  cancer1044     Prostate cancer                           1.7885e-33 0.9521
# 17  HC60           Oesophagitis/barretts oesophagus          1.0145e-27 0.7619
# 18  HC442          Chronic obstructive airways disease/COPD  1.2448e-26 1.0346
# 19  cancer1023     Rectal cancer                             1.3832e-26 0.8096
# 20  HC95           Inflammatory bowel disease                1.0206e-25 0.7187
# 21  HC326          Heart attack/myocardial infarction        9.9362e-25 0.4970
# 22  HC221          Diabetes                                  2.3451e-24 0.7996
# 23  HC55           Hyperthyroidism/thyrotoxicosis            6.3875e-21 0.4694
# 24  HC442          Chronic obstructive airways disease/COPD  1.3466e-20 0.4825
# 25  HC91           Psoriatic arthropathy                     1.1515e-19 0.8290
# 26  HC8            Gall bladder disease                      7.6999e-19 0.7335
# 27  HC442          Chronic obstructive airways disease/COPD  7.9579e-19 1.0665
# 28  HC294          Renal/kidney failure                      1.0544e-18 0.5570
# 29  BIN_FC10003591 Ever had hysterectomy (womb removed)      8.2850e-18 0.9960
# 30  HC442          Chronic obstructive airways disease/COPD  9.3728e-18 0.3495
# ⋮   ⋮              ⋮                                        ⋮           ⋮
# 153 HC61           Haemorrhoids / piles                     1.7999e-06   0.4046
# 154 HC423          Respiratory failure                      1.8068e-06   0.5969
# 155 HC430          Rheumatoid arthritis                     1.8744e-06   0.3086
# 156 HC221          Diabetes                                 1.9332e-06   0.3825
# 157 HC215          Hypertension                             1.9805e-06   0.2596
# 158 HC221          Diabetes                                 1.9969e-06   0.3388
# 159 HC219          Hypothyroidism/myxoedema                 2.0052e-06   0.1778
# 160 HC294          Renal/kidney failure                     2.1764e-06   0.4925
# 161 HC442          Chronic obstructive airways disease/COPD 2.1827e-06   0.3575
# 162 HC215          Hypertension                             2.2991e-06   0.2935
# 163 HC60           Oesophagitis/barretts oesophagus         2.5083e-06   0.4108
# 164 HC382          Asthma                                   2.5984e-06   0.2253
# 165 HC294          Renal/kidney failure                     2.6023e-06   0.3500
# 166 HC316          Dyspepsia / indigestion                  2.7336e-06   0.7979
# 167 cancer1001     Lung cancer                              2.8292e-06   0.4589
# 168 HC442          Chronic obstructive airways disease/COPD 2.8607e-06   0.4931
# 169 HC78           Arthritis                                2.9065e-06   0.2420
# 170 HC219          Hypothyroidism/myxoedema                 3.0022e-06   0.3503
# 171 HC222          Arterial embolism                        3.2314e-06   0.3130
# 172 HC442          Chronic obstructive airways disease/COPD 3.5273e-06   0.3513
# 173 HC221          Diabetes                                 3.5841e-06  -0.1817
# 174 HC326          Heart attack/myocardial infarction       3.6666e-06   0.3172
# 175 HC326          Heart attack/myocardial infarction       3.7559e-06   0.2313
# 176 HC78           Arthritis                                3.9068e-06   0.5345
# 177 HC326          Heart attack/myocardial infarction       3.9177e-06   0.3414
# 178 HC294          Renal/kidney failure                     4.0135e-06   0.7773
# 179 HC362          Respiratory infection                    4.3654e-06   0.6848
# 180 HC362          Respiratory infection                    4.4212e-06   0.5715
# 181 HC132          Angina                                   4.6008e-06   0.4308
# 182 HC422          Ankylosing spondylitis                   4.8474e-06  -0.3555
#     se     z        n_1    n_2
# 1   0.0111  89.9051  14938  12961
# 2   0.0249  38.0888   1981   2392
# 3   0.0036 278.7900  19168  16789
# 4   0.0124  78.6252   7166   9053
# 5   0.0274  36.8554   4382   3251
# 6   0.0284  32.8593   3147   3783
# 7   0.0341  26.7265   1096   1309
# 8   0.0404  21.7357  18471  12138
# 9   0.0317  17.7398  18471 107391
# 10  0.0280  16.7004 107391  20437
# 11  0.0421  16.0815  79397  43619
# 12  0.0693  14.1026  15942   7810
# 13  0.0402  13.5157 107391  12138
# 14  0.0696  12.8169   1852   1429
# 15  0.0400  12.5238  18471  20437
# 16  0.0790  12.0567   3448   6459
# 17  0.0698  10.9116  30224   9525
# 18  0.0969  10.6813   5599   7286
# 19  0.0759  10.6715   4382   2026
# 20  0.0685  10.4842   1652   3783
# 21  0.0484  10.2669  20437  12138
# 22  0.0785  10.1837   2311  20437
# 23  0.0500   9.3834  19917   3647
# 24  0.0519   9.3045  58111   7286
# 25  0.0914   9.0736   5074    954
# 26  0.0827   8.8643   1996   1637
# 27  0.1204   8.8606   8173   7286
# 28  0.0631   8.8292  20437   7081
# 29  0.1159   8.5956  15016  13772
# 30  0.0407   8.5814 107391   7286
# ⋮   ⋮      ⋮        ⋮      ⋮
# 153 0.0847  4.7747    2721  19958
# 154 0.1250  4.7739   58111   1819
# 155 0.0647  4.7665   19917   5586
# 156 0.0803  4.7603   15016  20437
# 157 0.0546  4.7554   13772 107391
# 158 0.0713  4.7537   13772  20437
# 159 0.0374  4.7529   88992  19917
# 160 0.1040  4.7363    2311   7081
# 161 0.0755  4.7357   12138   7286
# 162 0.0621  4.7252    6168 107391
# 163 0.0873  4.7075    7286   9525
# 164 0.0479  4.7003   20437  43619
# 165 0.0745  4.6999   14938   7081
# 166 0.1701  4.6899   30224  10001
# 167 0.0980  4.6828   58111   1981
# 168 0.1054  4.6806    3516   7286
# 169 0.0517  4.6773   19917  15330
# 170 0.0750  4.6707    2514  19917
# 171 0.0672  4.6555  107391    782
# 172 0.0757  4.6375   19446   7286
# 173 0.0392 -4.6341   19168  20437
# 174 0.0685  4.6294   14938  12138
# 175 0.0500  4.6245   19917  12138
# 176 0.1158  4.6163    4082  15330
# 177 0.0740  4.6157    8150  12138
# 178 0.1686  4.6107    6168   7081
# 179 0.1491  4.5932    4657   8173
# 180 0.1245  4.5905   30224   8173
# 181 0.0940  4.5822    5599  18471
# 182 0.0778 -4.5713    2294   1184
